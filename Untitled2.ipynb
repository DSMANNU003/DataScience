# %% [markdown]
# ipynb- extension of jupyter notebook, ipy - extension of python, markdown cell is used to write comments, kernel is used to execute different codes

# %%
print ("Hello Data Science World!!!")
# Out:
# Hello Data Science World!!!

# %% [raw]
# This green symbol in right side is for anaconda assistance

# %%
print("Manoj Sharma")
# Out:
# Manoj Sharma

# %%
24+26
# Out:
# 50

# %%
6*2
# Out:
# 12

# %% [markdown]
# upload the file on the homepage to see after downloading

# %%
# is used for single line comment and markdown is for multiple lines

# %% [markdown]
# insert the cell above the current cell - esp +A,,,,
# insert the cell below the cell - Esp+B,,,
# delete the cell - esp+D+D,,,
# execute the cell -  ctrl+enter , shift+enter
